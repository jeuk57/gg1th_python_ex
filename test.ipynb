# %% [markdown]
# vs-code에서 가상 환경 셋팅을 할 때 : ctrl + shift + p

# %%
print("헬로")
# Out:
# 헬로

# %%
import ollama

response = ollama.chat(
    model="exaone3.5:7.8b",
    messages=[
        {
            "role": "user",
            "content": "로컬 llm에 대해 설명해줘"
        }
    ]
)

print(response["message"]["content"])
# Out:
# "로컬 LLM"은 **사용자의 위치나 디바이스와 밀접하게 연관된 머신러닝 모델**을 의미합니다.
#
# **주요 특징은 다음과 같습니다:**
#
# * **저 지연 시간:** 클라우드 서버와의 통신 없이 로컬 장치에서 직접 처리되기 때문에 빠른 응답 속도를 제공합니다. 실시간 응용 분야에 매우 유용합니다. 예를 들어, 자율 주행 자동차에서 즉각적인 의사 결정이 필요한 상황에 적합합니다.
# * **오프라인 작동:** 인터넷 연결 없이도 작동 가능하여, 불안정한 네트워크 환경에서도 안정적인 성능을 보장합니다. 여행 중이나 데이터 제한 구역에서 유용합니다.
# * **개인 정보 보호 강화:** 사용자 데이터가 클라우드 서버로 전송되지 않으므로 개인 정보 보안 측면에서 이점이 있습니다. 특히 민감한 정보 처리에 적합합니다.
#
# **단점으로는:**
#
# * **모델 용량 제한:** 로컬 장치의 저장 공간 제약으로 인해 대형 모델을 실행하기 어려울 수 있습니다.
# * **지속적인 업데이트 어려움:** 새로운 데이터나 기능 추가를 위한 지속적인 학습 및 업데이트가 제한적일 수 있습니다.
#
# **예시:**
#
# * **휴대용 AI 번역기:** 실시간 번역 기능을 제공하며 인터넷 연결 없이도 사용 가능합니다.
# * **오프라인 음성 비서:** 스마트 스피커처럼 작동하지만, 인터넷 연결 없이도 기본적인 명령을 수행할 수 있습니다.
#
# 로컬 LLM은 특정 환경에서 뛰어난 성능을 발휘하며, 특히 실시간 처리, 오프라인 작동, 개인 정보 보호가 중요한 경우에 유용합니다. 하지만 모델 크기와 업데이트 측면에서 제약이 있음을 고려해야 합니다.
